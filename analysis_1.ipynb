# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.read_excel('sample_data.xlsx.xlsx')

# %%
data = pd.read_excel('sample_data.xlsx.xlsx')
data.head()#for the first members
# Out:
#    id first name last name  basic salary  d.a.  h.r.a  t.a department  fine
# 0   1        ram    sharma         30000   0.5    0.8  0.1      sale    600
# 1   2     vijay     pandey         25000   0.3    0.8  0.1   purchase   450
# 2   3      imran       ali         22000   0.5    0.8  0.1        rnd   500
# 3   4      rohan     kumar         18000   0.3    0.8  0.1      sales   200
# 4   5       sonu      jain         40000   0.5    0.8  0.1   purchase   100

# %%
data = pd.read_excel('sample_data.xlsx.xlsx')
data.tail()#for the last members
# Out:
#    id first name  last name  basic salary  d.a.  h.r.a  t.a department  fine
# 5   6    devansh    agarwal         70000   0.3    0.8  0.1        rnd   250
# 6   7      dhruv  srivastav         60000   0.4    0.6  0.1      sales   120
# 7   8  priyanshu      gupta         10000   0.2    0.1  0.1   purchase   230
# 8   9       aman  chaurasia         15000   0.2    1.0  0.5      sales   570
# 9  10    shubham     gautam         50000   0.1    0.7  0.1   purchase   850

# %%
data['first name']
# Out:
# 0          ram
# 1       vijay
# 2        imran
# 3        rohan
# 4         sonu
# 5      devansh
# 6        dhruv
# 7    priyanshu
# 8         aman
# 9      shubham
# Name: first name, dtype: object

# %%
data['basic salary'].mean()
# Out:
# 34000.0

# %%
data[['first name','basic salary','fine']]
# Out:
#   first name  basic salary  fine
# 0        ram         30000   600
# 1     vijay          25000   450
# 2      imran         22000   500
# 3      rohan         18000   200
# 4       sonu         40000   100
# 5    devansh         70000   250
# 6      dhruv         60000   120
# 7  priyanshu         10000   230
# 8       aman         15000   570
# 9    shubham         50000   850

# %%
data.set_index('id' , inplace=True)
data
# Out:
#    first name  last name  basic salary  d.a.  h.r.a  t.a department  fine
# id
# 1         ram     sharma         30000   0.5    0.8  0.1      sale    600
# 2      vijay      pandey         25000   0.3    0.8  0.1   purchase   450
# 3       imran        ali         22000   0.5    0.8  0.1        rnd   500
# 4       rohan      kumar         18000   0.3    0.8  0.1      sales   200
# 5        sonu       jain         40000   0.5    0.8  0.1   purchase   100
# 6     devansh    agarwal         70000   0.3    0.8  0.1        rnd   250
# 7       dhruv  srivastav         60000   0.4    0.6  0.1      sales   120
# 8   priyanshu      gupta         10000   0.2    0.1  0.1   purchase   230
# 9        aman  chaurasia         15000   0.2    1.0  0.5      sales   570
# 10    shubham     gautam         50000   0.1    0.7  0.1   purchase   850

# %%
data['basic salary'].plot()
# Out:
# <Axes: xlabel='id'>

# %%
data['basic salary'].plot.bar()
# Out:
# <Axes: xlabel='id'>

# %%
data['basic salary'].plot.area()
# Out:
# <Axes: xlabel='id'>

# %%
data['basic salary'].plot.box(figsize=(4,3))
# Out:
# <Axes: >

# %%
data['basic salary'].plot.pie()
# Out:
# <Axes: ylabel='basic salary'>

# %%
data['basic salary'].plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
data['basic salary'].plot.kde(figsize=(4,3))
# Out:
# <Axes: ylabel='Density'>

# %%
data['basic salary'].plot.pie(figsize=(4,4), autopct='%1f%%')
# Out:
# <Axes: ylabel='basic salary'>

# %%
data['total salary']=data['basic salary'] - data['fine'] + (data['h.r.a'] * data['basic salary'] ) +  (data['d.a.']* data['basic salary']) + (data['t.a'] * data['basic salary'])

# %%
data
# Out:
#    first name  last name  basic salary  d.a.  h.r.a  t.a department  fine  \
# id
# 1         ram     sharma         30000   0.5    0.8  0.1      sale    600
# 2      vijay      pandey         25000   0.3    0.8  0.1   purchase   450
# 3       imran        ali         22000   0.5    0.8  0.1        rnd   500
# 4       rohan      kumar         18000   0.3    0.8  0.1      sales   200
# 5        sonu       jain         40000   0.5    0.8  0.1   purchase   100
# 6     devansh    agarwal         70000   0.3    0.8  0.1        rnd   250
# 7       dhruv  srivastav         60000   0.4    0.6  0.1      sales   120
# 8   priyanshu      gupta         10000   0.2    0.1  0.1   purchase   230
# 9        aman  chaurasia         15000   0.2    1.0  0.5      sales   570
# 10    shubham     gautam         50000   0.1    0.7  0.1   purchase   850
#
#     total salary
# id
# 1        29820.0
# 2        24850.0
# 3        21808.0
# 4        18016.0
# 5        40460.0
# 6        70590.0
# ...

# %%
data[['total salary' , 'basic salary']].plot.bar(color=['#ff5555','green'])
# Out:
# <Axes: xlabel='id'>
